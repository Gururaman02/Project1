# %% [markdown]
# #30 days challenge day 1- Covering list,Tuple,Dictionary concepts
#
# Focus: Internals, Performance, Edge Cases, Patterns

# %% [markdown]
# ##1. Internals

# %% [markdown]
# ##Investigate

# %% [markdown]
# 1)List comprehensions and the basics of generator expressions;
# 2)Using tuples as records, versus using tuples as immutable lists;
# 3)Sequence unpacking and sequence patterns;
# 4)Reading from slices and writing to slices;
# 5)Specialized sequence types, like arrays and queues.

# %%
from collections import abc
issubclass(tuple, abc.Sequence)
# Out:
# True

# %%
issubclass(list, abc.Sequence)
# Out:
# True

# %%
list1=[1,2,3]
list1.__setitem__(0, 10)
print(list1)
list1.__delitem__(0)
print(list1)
print(list1.__getitem__(0))
print(list1.__len__())
list1.insert(0, 10)
print(list1)
print(list1.__contains__(10))
print(list1.__iter__()) 
print(list1.__reversed__())
print(list1.__str__())
print(list1.__repr__())
print(list1.reverse())
sorted_numbers = sorted(list1, reverse=True)
print(sorted_numbers)
print(list1.remove(10))
print(list1.extend([4,5,6]))
print(list1.pop(2))
# Out:
# [10, 2, 3]
# [2, 3]
# 2
# 2
# [10, 2, 3]
# True
# <list_iterator object at 0x000001AC780EAA40>
# <list_reverseiterator object at 0x000001AC780EAA40>
# [10, 2, 3]
# [10, 2, 3]
# None
# [10, 3, 2]
# None
# None
# 4

# %% [markdown]
# """
# ITER() – OVERVIEW
#
# Purpose:
# iter() returns an iterator object from an iterable (like list, tuple, dict, file).
#
# What is an iterator?
# An iterator is an object that allows sequential access to elements
# one at a time using next().
#
# Why we use it:
# 1. It powers Python's for-loops internally.
# 2. It enables memory-efficient processing (especially large files).
# 3. It allows controlled, step-by-step consumption of data.
# 4. It follows Python's Iterator Protocol (__iter__ and __next__).
#
# Important Concepts:
# - iter(obj) creates an iterator.
# - next(iterator) retrieves the next element.
# - When elements are exhausted, StopIteration is raised.
# - Iterators are stateful and get consumed as they progress.
# - Once exhausted, they cannot be reused (must create new iterator).
#
# Example:
#
# lst = [10, 20, 30]
# it = iter(lst)
#
# print(next(it))  # 10
# print(next(it))  # 20
# print(next(it))  # 30
# # next(it) -> raises StopIteration
#
# Key Difference:
# - Iterable (list) = reusable container.
# - Iterator = one-time sequential access object.
#
# Industry Use Cases:
# - Reading files line-by-line
# - Streaming large datasets
# - Database cursors
# - Generator-based pipelines
# """

# %%
symbols="@#@$#%$^%^%#"
codes=[]
for symbol in symbols:
    code=ord(symbol) #united code point of the character(unicode)
    codes.append(code)
print(codes)
# Out:
# [64, 35, 64, 36, 35, 37, 36, 94, 37, 94, 37, 35]

# %%
codes=[ord(symbol)for symbol in symbols]  ##list comprehension
print(codes)
# Out:
# [64, 35, 64, 36, 35, 37, 36, 94, 37, 94, 37, 35]

# %%
# multiline list comprehension example
symbols = '@#@$#%$^%^%#'
# produce numeric codes but skip punctuation
codes = [
    ord(sym)
    for sym in symbols
    if sym.isalnum()        # only letters/digits
]
print(codes)
# Out:
# []

# %%
#multiline list comprehension example as you can see we have 2 conditions loop and if statement one after another in 3 lines
symbols="A1$S@#!@"
codes=[ord(symbol) 
for symbol in symbols
if symbol.isalnum()  # check whether it's either digit or alphabet if not skip if it is print unicode for that example A=65
]

print(codes)
# Out:
# [65, 49, 83]

# %%
#listcomp vs map and filter
symbols="1){$S@#!@"
beyond_ascii = list(filter(lambda c: c > 75, map(ord,symbols))) 
print(beyond_ascii)
# Out:
# [123, 83]

# %%
symbols="{{%^$#$"
beyond_ascii=[ord(c) for c in symbols if ord(c)>12]
print(beyond_ascii)
# Out:
# [123, 123, 37, 94, 36, 35, 36]

# %%
_#cartesian product
#listcomp with nexted loops
sky=["blue","white"]
ground=["green","brown"]
colors=[(g,s) for g in ground
        for s in sky]
print(colors)
# Out:
# [('green', 'blue'), ('green', 'white'), ('brown', 'blue'), ('brown', 'white')]

# %%
for s in sky:
    for g in ground:
        colors.append((s,g))
print(colors)
# Out:
# [('green', 'blue'), ('green', 'white'), ('brown', 'blue'), ('brown', 'white'), ('blue', 'green'), ('blue', 'brown'), ('white', 'green'), ('white', 'brown')]

# %%
symbols="%@@#!@S^%^$"
tuple(ord(symbol) for symbol in symbols)
# Out:
# (37, 64, 64, 35, 33, 64, 83, 94, 37, 94, 36)

# %%
import array
array.array('i', [ord(symbol) for symbol in symbols]) 
#i is for signed integers-holds negative and positive numbers
# I is for unsigned integers- only holds positive numbers
# Out:
# array('i', [37, 64, 64, 35, 33, 64, 83, 94, 37, 94, 36])

# %%
#cartesian product with tuples
#process the cartesian product one item at a time
colors=['black','white']
sizes=['S','M','L']
for tshirt in (f'{c} {s}' for c in colors for s in sizes):
    print(tshirt)
# Out:
# black S
# black M
# black L
# white S
# white M
# white L

# %% [markdown]
# <VSCode.Cell language="markdown">
# ## Tuples: Immutable Lists vs. Records
#
# Tuples have two distinct use cases that exploit their immutability and fixed structure:
#
# ### 1. **Tuples as Immutable Lists**
# In this role, a tuple is like a list that **cannot be modified**. Use this when:
# - You want to prevent accidental or unintended changes to a collection.
# - You need to pass data that should not be altered by the recipient.
# - You want to use the sequence as a **dictionary key** (lists cannot be keys since they're mutable).
#
# ```python
# # Immutable list: protects data from modification
# coordinates = (10, 20, 30)
# # coordinates[0] = 100  # TypeError: 'tuple' object does not support item assignment
#
# # Can be used as dict key
# locations = {(0, 0): "origin", (1, 2): "elsewhere"}
# ```
#
# ### 2. **Tuples as Records (Unnamed Fields)**
# In this role, a tuple holds multiple values where **position encodes meaning**. Use this when:
# - You want a lightweight "struct" as an alternative to a class or named dictionary.
# - Each position represents a specific field (1st position = name, 2nd = age, 3rd = email, etc.).
# - You trade convenience for compactness and performance.
#
# ```python
# # Record: position encodes meaning (name, age, email)
# user = ("Alice", 30, "alice@example.com")
# name, age, email = user  # unpacking
#
# # vs. with a dict (redundant but explicit)
# user_dict = {"name": "Alice", "age": 30, "email": "alice@example.com"}
# ```
#
# ### Key Differences:
# | Aspect | Immutable List | Record |
# |--------|----------------|--------|
# | **Focus** | Protect a sequence from change | Bundle related values together |
# | **Field meaning** | Position is arbitrary | Position encodes semantic meaning |
# | **Access** | Index number (coordinates[0]) | Unpacking or index with assumed order |
# | **Scalability** | Good for any size | Better for small, fixed structures |
#
# > **Tip:** For records with many fields or optional fields, consider `namedtuple` or dataclasses instead—they provide named access while maintaining tuple efficiency.

# %%
# Tuples hold records: each item in the tuple holds the data for one field and the position of the item gives its meaning.

#here we group related data into single tuple
lax_coordinates=(33.9425, -118.408056)
latitude, longitude = lax_coordinates
print(latitude)
print(longitude)

#the below is tuple unpacking example
city, year, pop, chg, area = ('Tokyo', 2003, 32450, 0.66, 8014)
print(city)
print(year)
print(pop)
print(chg)
print(area)
# Out:
# 33.9425
# -118.408056
# Tokyo
# 2003
# 32450
# 0.66
# 8014

# %%
#list of tuples
traveller_ids=[('USA','31195855'),('BRA','CE342567'),('ESP','XDA205856')]
for passport in sorted(traveller_ids):
    print('%s/%s' % passport)
for country,_ in traveller_ids:
    print(country)
# Out:
# BRA/CE342567
# ESP/XDA205856
# USA/31195855
# USA
# BRA
# ESP

# %%
#tuples are immutable but if they contain mutable objects like list we can change the content of the list

a=(10,20,30,'alpha',[1,2,3])
b=(10,20,30,'alpha',[1,2,3])
print(a==b)
b[-1].append(4)
print(a)
print(b)
# Out:
# True
# (10, 20, 30, 'alpha', [1, 2, 3])
# (10, 20, 30, 'alpha', [1, 2, 3, 4])

# %%
#Tuple literals vs List literals
t=(1,2,3)
l=[1,2,3]
print(t.__sizeof__())
print(l.__sizeof__())

# Creating a tuple is faster than creating a list of the same size.
# tuple:
# The compiler already knows:
# This tuple will never change.
# It can treat it as a constant.
# So Python creates the entire tuple in one optimized operation.
# list:
# Python does:
# Push 1
# Push 2
# Push 3
# Build list from them

# Why?
# Because lists are mutable.
# They might change later.
# So Python must build them dynamically.

t = (1, 2, 3)
t2 = tuple(t)

print(t is t2)  # True

# Why?
# Because tuples are immutable.
# There is no need to create a new copy.
# They cannot change.

l = [1, 2, 3]
l2 = list(l)

print(l is l2)  # False
# Why?
# Because lists are mutable.
# If Python returned the same object,
# modifying one would modify the other.
# So it must create a new copy.

# Tuple = safe to reuse
# List = must protect from mutation

# The real difference is:
# Semantic meaning and safety.
# Tuple says:
# “This data should not change.”

# List says:
# “This data will change.”

# why dont we use tuples everywhere instead of lists?
# Because tuples are immutable.
# If you need to modify the data, you must use a list.
# Out:
# 48
# 72
# True
# False

# %%
# comparison and tuple methods example
s1 = (1, 1, 2, 3, [2, 4, 3.23])
s2 = (1, 1, 2, 3, [2, 4, 3.23])

# equality vs identity
print("s1 == s2:", s1 == s2)
print("s1 is s2:", s1 is s2)
print("id(s1):", id(s1))
print("id(s2):", id(s2))

# concatenation and repetition (produce new tuples)
print("s1 + s2:", s1.__add__(s2))
print("s1 * 3:", s1.__mul__(3))
# tuples are immutable, so these create new objects
# print(s1.__iadd__(s2))
# print(s1.__imul__(3))

# element queries
print("count of 1 in s1:", s1.count(1))
print("first index of 2 in s1:", s1.index(2))
print("contains 1:", 1 in s1)
print("contains 1 (dunder):", s1.__contains__(1))

# inspectors and iterators
print("iterator from tuple:", s1.__iter__())
print("string representation:", s1.__str__())
print("type of __str__():", type(s1.__str__()))
print("repr:", s1.__repr__())
print("first element:", s1.__getitem__(0))
print("length:", s1.__len__())
print("rmul example:", s1.__rmul__(5))

# unsupported operations (commented out)
# s1.__delitem__(0)   # tuples are immutable
# s1.sort()           # tuples have no sort method
# Out:
# s1 == s2: True
# s1 is s2: False
# id(s1): 1840260195136
# id(s2): 1840260504672
# s1 + s2: (1, 1, 2, 3, [2, 4, 3.23], 1, 1, 2, 3, [2, 4, 3.23])
# s1 * 3: (1, 1, 2, 3, [2, 4, 3.23], 1, 1, 2, 3, [2, 4, 3.23], 1, 1, 2, 3, [2, 4, 3.23])
# count of 1 in s1: 2
# first index of 2 in s1: 2
# contains 1: True
# contains 1 (dunder): True
# iterator from tuple: <tuple_iterator object at 0x000001AC78134EB0>
# string representation: (1, 1, 2, 3, [2, 4, 3.23])
# type of __str__(): <class 'str'>
# repr: (1, 1, 2, 3, [2, 4, 3.23])
# first element: 1
# length: 5
# rmul example: (1, 1, 2, 3, [2, 4, 3.23], 1, 1, 2, 3, [2, 4, 3.23], 1, 1, 2, 3, [2, 4, 3.23], 1, 1, 2, 3, [2, 4, 3.23], 1, 1, 2, 3, [2, 4, 3.23])

# %%
# start with a list
nums = [5, 2, 9, 1, 7, 4] 
# 1. sort in place, largest first 
nums.sort(reverse=True) 
print(nums) # [9, 7, 5, 4, 2, 1] # 2. sort by a computed key and reverse the result 
# (here: group by remainder mod 3, highest groups first)
nums = [5, 2, 9, 1, 7, 4] 
nums.sort(key=lambda x: x % 3, reverse=True) 
print(nums)
 # e.g. [5, 2, 8…] – elements with larger keys come first
# Out:
# [9, 7, 5, 4, 2, 1]
# [5, 2, 1, 7, 4, 9]

# %%
# Q1 — Tuple with Mutable Inside

a = (1, 2, [3, 4])
b = tuple(a)

b[2].append(5)

print(a)

# OUTPUT:
# (1, 2, [3, 4, 5])

# EXPLANATION:
# tuple(a) does NOT create a deep copy.
# Since 'a' is already a tuple, b refers to the SAME tuple object.
# The inner list [3,4] is shared.
# append() modifies the inner list, so 'a' changes.
# Out:
# (1, 2, [3, 4, 5])

# %%
# Q2 — += vs +

# Case 1: += (in-place modification)
x = [1,2,3]
y = x
x += [4,5]

print(y)

# OUTPUT:
# [1,2,3,4,5]

# EXPLANATION:
# += calls __iadd__() for lists.
# It modifies the SAME list object in memory.
# x and y both refer to the same list.


# Case 2: + (new object created)
x = [1,2,3]
y = x
x = x + [4,5]

print(y)

# OUTPUT:
# [1,2,3]

# EXPLANATION:
# x + [4,5] creates a NEW list object.
# x now refers to new object.
# y still refers to old list.
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3]

# %%
# Q3 — Sorting does NOT protect inner objects

records = [
    ("Alice", [80, 90]),
    ("Bob", [70, 85]),
]

records.sort(key=lambda x: sum(x[1]))

records[0][1].append(100)

print(records)

# OUTPUT:
# Inner list is modified.

# EXPLANATION:
# sort() only rearranges references in outer list.
# It does NOT copy tuples or inner lists.
# Inner list objects remain shared and mutable.
# Out:
# [('Bob', [70, 85, 100]), ('Alice', [80, 90])]

# %%
# Q4 — Generator Exhaustion

gen = (x*x for x in range(3))

print(list(gen))
print(list(gen))

# OUTPUT:
# [0, 1, 4]
# []

# EXPLANATION:
# Generator is an iterator.
# First list(gen) consumes all values.
# Generator becomes exhausted.
# Second call produces empty list.
# Generators are one-time use.
# Out:
# [0, 1, 4]
# []

# %%
# Q5 — Memory: List vs Generator

# List comprehension
lst = [x*x for x in range(1_000_000)]

# Generator expression
gen = (x*x for x in range(1_000_000))

# EXPLANATION:
# List comprehension stores ALL values in memory (O(n)).
# Generator produces one value at a time (O(1) memory).

# %%
# Q6 — Slice Assignment Changing Length

a = [1,2,3,4]
b = a[:]

b[1:3] = [100,200,300]

print(b)

# OUTPUT:
# [1, 100, 200, 300, 4]

# EXPLANATION:
# Slice [1:3] selects 2 elements: [2,3]
# Replacing with 3 elements expands list.
# Slice assignment can change list length.
# Out:
# [1, 100, 200, 300, 4]

# %%
# Q7 — Nested Comprehension Order

ground = ["green","brown"]
sky = ["blue","white"]

colors = [(g,s) for g in ground for s in sky]
print(colors)

# EXPLANATION:
# Equivalent to:
# for g in ground:
#     for s in sky:
# Outer loop controls grouping.
# Changing order changes output order.
# Out:
# [('green', 'blue'), ('green', 'white'), ('brown', 'blue'), ('brown', 'white')]

# %%
# Q8 — 'in' Operator

list1 = [1,2,3,4]

print(3 in list1)

# EXPLANATION:
# Calls list1.__contains__(3)
# List performs linear scan.
# Time complexity: O(n)
# For set: O(1) average (hash lookup).
# Out:
# True

# %%
# Q9 — Shallow Copy Trap

a = [[1,2],[3,4]]
b = a.copy()
c = list(a)

b[0].append(9)
c[1].append(10)

print(a)

# OUTPUT:
# [[1,2,9],[3,4,10]]

# EXPLANATION:
# .copy() and list(a) create shallow copies.
# Outer list is new.
# Inner lists are shared.
# Mutating inner lists affects original.
# Out:
# [[1, 2, 9], [3, 4, 10]]

# %%
# Q10 — Tuple += Creates New Object

t = (1,2,3)
id_before = id(t)

t += (4,)
id_after = id(t)

print(id_before == id_after)

# OUTPUT:
# False

# EXPLANATION:
# Tuple is immutable.
# += creates a NEW tuple.
# ID changes.
# Unlike list, no in-place modification.
# Out:
# False
